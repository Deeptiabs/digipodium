# %%
2+2
# Out:
# 4

# %%
X=10
Y=3
name='deepti'

# %%
X+Y
# Out:
# 13

# %%
X-Y
# Out:
# 7

# %%
X*Y
# Out:
# 30

# %%
X/Y
# Out:
# 3.3333333333333335

# %%
X//Y
# Out:
# 3

# %%
X**Y
# Out:
# 1000

# %% [markdown]
# Operators
# - arithmetic
# - assignment
# - comparison
# - logical
# - membership
# - identity

# %%
X+=5

# %%
Y-=5

# %%
not X
# Out:
# False

# %%
Z=0
not Z
# Out:
# True
