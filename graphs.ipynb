# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rainfall=[17,10,10,10,26,50]
months=['jan','feb','mar','apr','may','jun']

# %%
plt.style.available
plt.style.use('ggplot') #theme
plt.bar(months,rainfall,color='#585555')

# %%
plt.pie(
    rainfall,
    labels=months,
    autopct='%1.1f%%',
)
plt.show()

# %%
#donut
plt.pie(
    rainfall,
    labels=months,
    autopct='%1.1f%%',
    wedgeprops={'width':0.4,'edgecolor':'#6666ff'},
    pctdistance=0.7
)
plt.show()

# %%
plt.boxplot(rainfall,
    vert=False,
    showmeans=True,
    meanline=True,
    meanprops={'color':'red'}
    )
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3],label='kuch bhi')  # Plot some data on the axes.
ax.grid()
ax.legend() #add a legend

# %%
fig, ax = plt.subplots(figsize=(5,5))  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3],label='kuch bhi')  # Plot some data on the axes.
ax.plot([1, 2, 3, 4], [3,2,4, 3],label='kuch bhi nhi') 
ax.grid()
ax.legend() #add a legend

# %%
t=np.arange(-10,10,.2)
y=np.sin(t)
fig,ax=plt.subplots(figsize=(10,3))
ax.plot(t,y,label='sin wave',color='red',linestyle=':',linewidth=3,marker='x',markersize=5,alpha=.9)
ax.grid()
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
t=np.arange(-10,10,.2)
y=np.cos(t)
fig,ax=plt.subplots(figsize=(10,3))
ax.plot(t,y,label='cos wave',color='red',linestyle=':',linewidth=3,marker='x',markersize=5,alpha=.9)
ax.grid()
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
t=np.arange(-10,10,.2)
y=np.sin(t)
y2=np.cos(t)
fig,ax=plt.subplots(figsize=(10,3))
ax.plot(t,y,label='sin wave',color='red',linestyle=':',linewidth=3,marker='x',markersize=5,alpha=.9)
ax.plot(t,y2,label='cos wave',color='black',linestyle=':',linewidth=3,marker='x',markersize=5,alpha=.9)
ax.grid()
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
t=np.arange(-10,10,.2)
y=np.sin(t)
y2=np.tan(t)
fig,ax=plt.subplots(figsize=(10,3))
ax.plot(t,y,label='sin wave',color='red',linestyle=':',linewidth=3,marker='x',markersize=5,alpha=.9)
ax.plot(t,y2,label='tan wave',color='black',linestyle=':',linewidth=3,marker='x',markersize=5,alpha=.9)
ax.grid()
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph.
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# %%
fig, ax = plt.subplots()
t = np.linspace(0, 3, 40)
g = -9.81
v0 = 12
z = g * t**2 / 2 + v0 * t

v02 = 5
z2 = g * t**2 / 2 + v02 * t

scat = ax.scatter(t[0], z[0], c="b", s=5, label=f'v0 = {v0} m/s')
line2 = ax.plot(t[0], z2[0], label=f'v0 = {v02} m/s')[0]
ax.set(xlim=[0, 3], ylim=[-4, 10], xlabel='Time [s]', ylabel='Z [m]')
ax.legend()


def update(frame):
    # for each frame, update the data stored on each artist.
    x = t[:frame]
    y = z[:frame]
    # update the scatter plot:
    data = np.stack([x, y]).T
    scat.set_offsets(data)
    # update the line plot:
    line2.set_xdata(t[:frame])
    line2.set_ydata(z2[:frame])
    return (scat, line2)


ani = animation.FuncAnimation(fig=fig, func=update, frames=40, interval=30)
plt.show()
